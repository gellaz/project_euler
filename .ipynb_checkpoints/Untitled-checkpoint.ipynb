# %%
from itertools import combinations 
  
comb = combinations(range(97, 122), 2)
xors = [c[0] ^ c[1] for c in comb]

for i in list(comb): 
    print(i[0] ^ i[1])

# %%
xors
# Out:
# [3,
#  2,
#  5,
#  4,
#  7,
#  6,
#  9,
#  8,
#  11,
#  10,
#  13,
#  12,
#  15,
#  14,
#  17,
#  16,
#  19,
#  18,
#  21,
#  20,
#  23,
#  22,
#  25,
#  24,
#  1,
#  6,
#  7,
#  4,
#  5,
#  10,
#  11,
#  8,
#  9,
#  14,
#  15,
#  12,
#  13,
#  18,
#  19,
#  16,
#  17,
#  22,
#  23,
#  20,
#  21,
#  26,
#  27,
#  7,
#  6,
#  5,
#  4,
#  11,
#  10,
#  9,
#  8,
#  15,
#  14,
#  13,
#  12,
#  19,
#  18,
#  17,
#  16,
#  23,
#  22,
#  21,
#  20,
#  27,
#  26,
#  1,
#  2,
#  3,
#  12,
#  13,
#  14,
#  15,
#  8,
#  9,
#  10,
#  11,
#  20,
#  21,
#  22,
#  23,
#  16,
#  17,
#  18,
#  19,
#  28,
#  29,
#  3,
#  2,
#  13,
#  12,
#  15,
#  14,
#  9,
#  8,
#  11,
#  10,
#  21,
#  20,
#  23,
#  22,
#  17,
#  16,
#  19,
#  18,
#  29,
#  28,
#  1,
#  14,
#  15,
#  12,
#  13,
#  10,
#  11,
#  8,
#  9,
#  22,
#  23,
#  20,
#  21,
#  18,
#  19,
#  16,
#  17,
#  30,
#  31,
#  15,
#  14,
#  13,
#  12,
#  11,
#  10,
#  9,
#  8,
#  23,
#  22,
#  21,
#  20,
#  19,
#  18,
#  17,
#  16,
#  31,
#  30,
#  1,
# ...
